# %% [markdown]
# # Frequency
# ## Keeno Glanville
# ### Star Wars dialogue

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in data
df = pd.read_csv('starwars.csv')

# %%
yoda= df[df['character'] == 'YODA']

# %%
yoda.head(10)
# Out:
#     movie  scene  line character  \
# 4       1    129  1162      YODA
# 6       1    129  1164      YODA
# 9       1    129  1167      YODA
# 11      1    129  1169      YODA
# 13      1    129  1171      YODA
# 15      1    129  1173      YODA
# 20      1    129  1178      YODA
# 23      1    129  1181      YODA
# 26      1    129  1184      YODA
# 30      1    134  1261      YODA
#
#                                                  text  \
# 4   The very Republic is threatened, if involved t...
# 6   Hard to see, the dark side is. Discover who th...
# 9   With this Naboo queen you must stay, Qui-Gon. ...
# 11                         May the Force be with you.
# 13      (Cont'd) Master Qui-Gon more to say have you?
# 15                               A vergence, you say?
# 20             But you do! Rrevealed your opinion is.
# 23            Trained as a Jedi, you request for him?
# 26                                 Tested he will be.
# 30               Good, good, young one. How feel you?
#
#                                                  slug  component
# 4    INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 6    INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 9    INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 11   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 13   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 15   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 20   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 23   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 26   INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY  character
# 30  INT. PALACE OF THE JEDI - COUNCIL CHAMBERS - S...  character

# %%
#Creating the Corpus for unique words
corpus_text = ' '.join(yoda['text'])
words = corpus_text.split()
unique_words = set(words)
total_unique_words = len(unique_words)
total_unique_words
# Out:
# 558

# %%
unique_words
# Out:
# {"(Cont'd)",
#  '(continuing)',
#  '.',
#  '...',
#  '...Correct',
#  'A',
#  'Act',
#  'Afraid',
#  'Agree,',
#  'Allow',
#  'Already',
#  'Always',
#  'An',
#  'Anakin.',
#  'Ancient',
#  'And',
#  'Anger,',
#  'At',
#  'Attachment',
#  'But',
#  'By',
#  'Careful',
#  'Chancellor',
#  'Chancellor,',
#  'Chewbacca',
#  'Chosen',
#  'Clones',
#  'Clouded,',
#  'Commander.',
#  'Confer',
#  'Congress',
#  'Consumed',
#  'Coucil',
#  'Council',
#  'Darth',
#  'Death',
#  'Destroy',
#  'Discover',
#  'Dismantle',
#  'Disturbing',
#  'Done,',
#  'Droid',
#  'Earned',
#  'Emperor,',
#  'Eternal',
#  'Even',
#  'Eveything.',
#  'Failed',
#  'Failed,',
#  'Faith',
#  'Fear',
#  'For',
#  'Force',
#  'Force,',
#  'Force.',
#  'Force...',
#  'General',
#  'Go,',
#  'Good',
#  'Good,',
#  'Good-bye.',
#  'Grievous',
#  'Hard',
#  'Heard',
#  'Hidden,',
#  'Hiding',
#  'Hmm.',
#  'Hmmmm',
#  'Hmmmmm.',
#  'Hope,',
#  'How',
#  'Hurry.',
#  'I',
#  'If',
#  'Impossible,',
#  'In',
#  'Into',
#  'Jedi',
#  "Jedi's",
#  'Jedi,',
#  'Jinn.',
#  'Kashyyyk,',
#  'Kenobi,',
#  'Killed',
#  'Knight',
#  'Look',
#  'Lord',
#  'Lord,',
#  'Luke...Luke...Do',
#  'Masked',
#  'Master',
#  'Master,',
#  'May',
#  'Miss',
#  'Mmm...',
#  'More',
#  'Mourn',
#  'Much',
#  'Naboo',
#  'Need',
#  'No',
#  'Not',
#  'Obi-Wan,',
#  'One',
#  'Order',
#  'Our',
#  'Outer',
#  'Padawan',
#  'Padawan.',
#  'Palpatine.',
#  'Pregnant,',
#  'Premonitions',
#  'Protect',
#  "Queen's",
#  'Qui-Gon',
#  "Qui-Gon's",
#  'Qui-Gon.',
#  'Quickly',
#  'Ready',
#  'Received',
#  'Rejoice',
#  'Remember,',
#  'Republic',
#  'Rim,',
#  'Rrevealed',
#  'Save',
#  'See',
#  'Sidious,',
#  'Sidious.',
#  'Sith',
#  'Sith,',
#  'Skywalker',
#  "Skywalker's",
#  'Soon',
#  'Split',
#  'Still',
#  'Stink,',
#  'Strong',
#  'Suggest',
#  'Surprised?',
#  'Take',
#  'Tarfful,',
#  'Tatooine,',
#  'Tatooine.',
#  'Temple',
#  'Tested',
#  'That',
#  'The',
#  'Then',
#  'They',
#  'To',
#  'Told',
#  'Too',
#  'Train',
#  'Trained',
#  'Twilight',
#  'Twisted',
#  'Unexpected',
#  'Until',
#  'Use',
#  'Vader.',
#  'Visit',
#  'What',
#  'Whills,',
#  'With',
#  'Wookiees,',
#  'Yes,',
#  'Yes...',
#  'Young',
#  'Your',
#  'Yourself',
#  'a',
#  'about',
#  'agree',
#  'agree.',
#  'all,',
#  'am',
#  'an',
#  'and',
#  'anger',
#  'anger...',
#  'anything',
#  'appear.',
#  'appointment',
#  'apprentice',
#  'apprentice,',
#  'apprentice.',
#  'are',
#  'are,',
#  'are.',
#  'are....no',
#  'armies',
#  'around',
#  'as',
#  'assassin',
#  'attacker.',
#  'back',
#  'back,',
#  'barely',
#  'bathe,',
#  'be',
#  'be,',
#  'be.',
#  'be;',
#  'become',
#  'become,',
#  'become.',
#  'been.',
#  'beware.',
#  'boy',
#  "boy's",
#  'but',
#  'by',
#  'call',
#  'can',
#  'can.',
#  'capture',
#  'care',
#  'carry',
#  'change',
#  'children',
#  'choice',
#  'clones,',
#  'close',
#  'coded',
#  'commitment,',
#  'commune',
#  'consciousness',
#  'consciousness.',
#  'contact,',
#  'continue,',
#  'could',
#  'council',
#  'danger',
#  'dark',
#  'decided',
#  'decisively',
#  'deepest',
#  'defiance',
#  'destroy',
#  'destroy.',
#  'did',
#  'did.',
#  'disappear',
#  'discover',
#  'discovered',
#  'dismantling',
#  'do',
#  'do!',
#  'does',
#  'does.',
#  'draw',
#  'early,',
#  'easier',
#  'emergency',
#  'end',
#  'enough',
#  'enough,',
#  'enter',
#  'escape,',
#  'everything',
#  'exile',
#  'experience.',
#  'eyes?',
#  'face',
#  'faith',
#  'family,',
#  'far,',
#  'fate',
#  'father',
#  'fear',
#  'feel',
#  'feelings,',
#  'fight',
#  'find',
#  'find.',
#  'flows',
#  'for',
#  'forever',
#  'friend',
#  'friends',
#  'from',
#  'future',
#  'future,',
#  'give',
#  'go',
#  'go,',
#  'go.',
#  'gone',
#  'good,',
#  'gratefully',
#  'gratitude',
#  'grave',
#  'great',
#  'greater',
#  'greed,',
#  'group',
#  'has',
#  'has...',
#  'hate',
#  'hate..',
#  'have',
#  'have,',
#  'have.',
#  'he',
#  'he?',
#  'hear',
#  'help',
#  'help,',
#  'her.',
#  'her..I',
#  'him',
#  'him,',
#  'him.',
#  'him?',
#  'his',
#  'hope',
#  'hope.',
#  'if',
#  'immortality.',
#  'in',
#  'influence',
#  'into',
#  'involved',
#  'is',
#  'is,',
#  'is.',
#  'it',
#  'it,',
#  'jealousy.',
#  'join',
#  'just',
#  'keep',
#  'kept.',
#  'know',
#  'know?',
#  'knowledge',
#  'last',
#  'later.',
#  'leads',
#  'learn,',
#  'learned',
#  'learner,',
#  'leave??',
#  'less.',
#  'let',
#  'level',
#  'life.',
#  'light',
#  'lightly,',
#  'lightsaber,',
#  'line',
#  'line.',
#  'little',
#  'long',
#  'longer',
#  'lose',
#  'lose.',
#  'loss',
#  'make.',
#  'master',
#  'may',
#  'me',
#  'me.',
#  'message,',
#  'might',
#  'mind.',
#  'misplaced',
#  'misread',
#  'miss',
#  'moment',
#  'moment.',
#  'more',
#  'more...no',
#  'most',
#  'move',
#  'much',
#  'mud',
#  'must',
#  'must,',
#  'must.',
#  'my',
#  'natural',
#  'need.',
#  'needed,',
#  'netherworld',
#  'nevertheless,',
#  'new',
#  'no',
#  'not',
#  'not!',
#  'not.',
#  'not...Do',
#  'now',
#  'of',
#  'of,',
#  'old',
#  'on',
#  'one',
#  'one,',
#  'one.',
#  'only',
#  'opinion',
#  'or',
#  'our',
#  'ourselves',
#  'out',
#  'outlying',
#  'own',
#  'pain',
#  'part',
#  'path',
#  'perhaps.',
#  'physical',
#  'place',
#  'power',
#  'powerful',
#  'powers',
#  'powers.',
#  'premonitions',
#  'pride',
#  'proceed.',
#  'prophecy',
#  'queen',
#  'question,',
#  'quickly.',
#  'ready.',
#  'ready?',
#  'recalibration,',
#  'recordings',
#  'relations',
#  'request',
#  'require.',
#  'respect,',
#  'rest',
#  'rest.',
#  'retain,',
#  'retreat',
#  'returned',
#  'right',
#  'right,',
#  'rule',
#  'runs,',
#  'safe,',
#  'say',
#  'say.',
#  'say?',
#  'second.',
#  'secret',
#  'security',
#  'see',
#  'see,',
#  'self,',
#  'send',
#  'sense',
#  'sensing',
#  'serious',
#  'session',
#  'shadow',
#  'she',
#  'ship.',
#  'short',
#  'should',
#  'side',
#  'side,',
#  'side.',
#  'side...',
#  'signal',
#  'signal,',
#  'sleep.',
#  'so',
#  'solitude',
#  'someone',
#  'soon',
#  'speak',
#  'special',
#  'spies',
#  'stay,',
#  'still',
#  'still.',
#  'stop',
#  'strength',
#  'strong',
#  'strong!',
#  'studied.',
#  'suffering.',
#  'sway',
#  'sweep.',
#  'systems,',
#  'take',
#  'take.',
#  'taking',
#  'task',
#  'teach',
#  'than',
#  'that',
#  'that,',
#  'the',
#  'them,',
#  'then',
#  'there',
#  'there,',
#  'these',
#  'these.',
#  'they',
#  'think.',
#  'this',
#  'this,',
#  'those',
#  'thought',
#  'threatened,',
#  'through',
#  'time',
#  'times',
#  'timing',
#  'to',
#  'train',
#  'trained,',
#  'training',
#  'training.',
#  'transform',
#  'two',
#  'under',
#  'underestimate',
#  'unfortunate...',
#  'up,',
#  'upon',
#  'us',
#  'us.',
#  'vergence,',
#  'very',
#  'visions',
#  'wait',
#  'wait.',
#  'war.',
#  'was,',
#  'was.',
#  'way.',
#  'we',
#  'we,',
#  'we.',
#  'were,',
#  'when',
#  'which',
#  'who',
#  'why',
#  'will',
#  'will,',
#  'will.',
#  'with',
#  'you',
#  'you,',
#  'you.',
#  'you?',
#  'young',
#  'your',
#  'yourself',
#  'youth.'}

# %%
# Determine the number of unique words representing half of the total words
word_frequencies = pd.Series(words).value_counts()
cumulative_sum = word_frequencies.cumsum()
half_total_words = cumulative_sum[cumulative_sum <= len(words) / 2].index[-1]
unique_words_half_total = len(unique_words & set(half_total_words))
unique_words_half_total
# Out:
# 1

# %%
# Step 4: Identify the 200 highest frequency words
top200 = word_frequencies.head(200).index.tolist()
top200
# Out:
# ['the',
#  '.',
#  'you',
#  'I',
#  'to',
#  'of',
#  'will',
#  'is',
#  'a',
#  'we',
#  'is.',
#  'this',
#  'with',
#  'your',
#  'you.',
#  'have',
#  'in',
#  'and',
#  'must',
#  'The',
#  'A',
#  'he',
#  'dark',
#  'on',
#  'not.',
#  'be',
#  'have.',
#  'it',
#  'Master',
#  'are',
#  'To',
#  'you?',
#  'Force',
#  'do',
#  'will.',
#  'fear',
#  'by',
#  'there',
#  'be.',
#  'much',
#  'you,',
#  'from',
#  'his',
#  'apprentice,',
#  'for',
#  'young',
#  'Your',
#  'as',
#  'Kenobi,',
#  'that',
#  'Good',
#  'who',
#  'Force.',
#  'time',
#  'May',
#  'must.',
#  'Jedi',
#  'leads',
#  'more',
#  'is,',
#  '(continuing)',
#  'not',
#  'Emperor,',
#  'need.',
#  'path',
#  'them,',
#  'are.',
#  'our',
#  'Skywalker',
#  'new',
#  'has',
#  'train',
#  'Qui-Gon.',
#  'coded',
#  'Qui-Gon',
#  'him',
#  'But',
#  'should',
#  'How',
#  'so',
#  'old',
#  'him.',
#  'does.',
#  'boy',
#  'If',
#  'but',
#  'In',
#  'Master,',
#  'still',
#  'may',
#  'Force,',
#  'Train',
#  'Strong',
#  'one',
#  'find',
#  'One',
#  'For',
#  'That',
#  'an',
#  'learn,',
#  'great',
#  'take.',
#  'agree.',
#  'my',
#  'Obi-Wan,',
#  'Quickly',
#  'end',
#  'now',
#  'Not',
#  'Hurry.',
#  'Destroy',
#  'Too',
#  'Wookiees,',
#  '...',
#  'Lord',
#  'become.',
#  'Grievous',
#  'Darth',
#  'place',
#  'Sidious.',
#  'it,',
#  'into',
#  'apprentice',
#  'when',
#  'Careful',
#  'or',
#  'And',
#  'Jinn.',
#  'no',
#  'say',
#  'With',
#  'side',
#  'anger',
#  'me',
#  'know',
#  'Sith',
#  'Afraid',
#  'if',
#  'training',
#  'An',
#  'rest.',
#  'Then',
#  'sense',
#  'council',
#  'pain',
#  'only',
#  'By',
#  'go,',
#  'recordings',
#  'security',
#  'Already',
#  'still.',
#  'Clones',
#  'was.',
#  'which',
#  'back,',
#  'change',
#  'long',
#  'recalibration,',
#  'Mmm...',
#  'discover',
#  'lightsaber,',
#  'longer',
#  'Sith,',
#  'require.',
#  'find.',
#  'Vader.',
#  'Consumed',
#  'Yes,',
#  'gone',
#  'trained,',
#  'forever',
#  'sleep.',
#  'Earned',
#  'side,',
#  'Twisted',
#  'enough,',
#  'strong',
#  'Sidious,',
#  'am',
#  'Force...',
#  'strong!',
#  'Twilight',
#  'upon',
#  'fight',
#  'Padawan.',
#  'No',
#  'rest',
#  'Killed',
#  'Yes...',
#  'ourselves',
#  'session',
#  'special',
#  'beware.',
#  'way.',
#  'light',
#  'might',
#  'knowledge',
#  'little',
#  'Anger,']

# %%
#Relative frequency of the 200 words
top_200_word_frequencies = word_frequencies.loc[top200]
plt.figure(figsize=(20, 20))
plt.bar(range(len(top200)), top_200_word_frequencies)
plt.xticks(range(len(top200)), top200, rotation=90)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 200 Word Frequencies (Yoda)')
plt.tight_layout()
plt.show()
